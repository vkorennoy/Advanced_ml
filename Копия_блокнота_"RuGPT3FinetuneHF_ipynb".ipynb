# %% [markdown]
# <a href="https://colab.research.google.com/github/vkorennoy/Advanced_ml/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22RuGPT3FinetuneHF_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Finetune RuGPTs in huggingface
# How to finetune RuGPTs models with huggingface. Example for RuGPT3Small. Nfor other models it will take more GPU memory.
#
# This notebook is valid for all RuGPTs models except RuGPT3XL.
# ## Install env

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==1.4.0
# !pip3 install transformers==3.5.0
# Out:
# ...
#      |████████████████████████████████| 753.4 MB 6.7 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# ...
#      |████████████████████████████████| 1.3 MB 12.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 63.1 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 45.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 74.1 MB/s
# ...

# %%
# !git clone  https://github.com/sberbank-ai/ru-gpts
# Out:
# Cloning into 'ru-gpts'...
# remote: Enumerating objects: 663, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 663 (delta 97), reused 127 (delta 76), pack-reused 505
# Receiving objects: 100% (663/663), 396.66 KiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (397/397), done.

# %%
# !mkdir models/

# %% [markdown]
# ## Download files

# %%
# !wget -O train.txt https://www.dropbox.com/s/oa3v9c7g9bp40xw/train.txt?dl=0
# !wget -O valid.txt https://www.dropbox.com/s/mworl3ld6r3bg62/valid.txt?dl=0
# Out:
# --2021-11-12 20:32:37--  https://www.dropbox.com/s/oa3v9c7g9bp40xw/train.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/oa3v9c7g9bp40xw/train.txt [following]
# --2021-11-12 20:32:37--  https://www.dropbox.com/s/raw/oa3v9c7g9bp40xw/train.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5ad8636d45f0c21c97e977f013.dl.dropboxusercontent.com/cd/0/inline/BZ160Tkgspa16nLAwu2tSOf4EDWbiP9EbNnhJhFUze6WWY7TCdcevNZ3h0NAijNSKAwTaoZlR6yS4pQE2lK1R9UY_ROD8qOlboGlzvZbnykh-P4G8Vd1aIshAjNJeiAg7dJNIhk2-D2vlmyr3Rns1M4t/file# [following]
# ...

# %% [markdown]
# ## Train
# The following code download our model and tokenizer from huggingface and finetune model for generating essays.
#
# This took aroung ten minutes and obtain perplexity = 13-16

# %%
# !export PYTHONPATH=${PYTHONPATH}:/ru-gpts/
# !CUDA_VISIBLE_DEVICES=0 python ru-gpts/pretrain_transformers.py \
    --output_dir=drive/MyDrive/AI-dungeon/models/VK_test_mixed_dataset_gpt3_medium \
    --model_type=gpt2 \
    --model_name_or_path=sberbank-ai/rugpt3medium_based_on_gpt2 \
    --do_train \
    --train_data_file=drive/MyDrive/AI-dungeon/datasets/mix_translations_cyoa_fantasy_fairitailes.txt \
    --per_gpu_train_batch_size 1 \
    --gradient_accumulation_steps 1 \
    --num_train_epochs 5 \
    --block_size 1024 \
    --overwrite_output_dir \
    --logging_steps 1000 \
    --save_steps 1000 \
    # --save_total_limit 5 
    #\
    #--fp16
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Iteration:  83% 12273/14751 [2:12:03<25:47,  1.60it/s]
# Iteration:  83% 12274/14751 [2:12:04<25:38,  1.61it/s]
# Iteration:  83% 12275/14751 [2:12:04<25:33,  1.61it/s]
# Iteration:  83% 12276/14751 [2:12:05<25:27,  1.62it/s]
# Iteration:  83% 12277/14751 [2:12:06<25:28,  1.62it/s]
# Iteration:  83% 12278/14751 [2:12:06<26:02,  1.58it/s]
# Iteration:  83% 12279/14751 [2:12:07<25:51,  1.59it/s]
# Iteration:  83% 12280/14751 [2:12:07<25:46,  1.60it/s]
# Iteration:  83% 12281/14751 [2:12:08<25:42,  1.60it/s]
# Iteration:  83% 12282/14751 [2:12:09<25:38,  1.61it/s]
# Iteration:  83% 12283/14751 [2:12:09<25:45,  1.60it/s]
# Iteration:  83% 12284/14751 [2:12:10<25:47,  1.59it/s]
# Iteration:  83% 12285/14751 [2:12:11<25:43,  1.60it/s]
# Iteration:  83% 12286/14751 [2:12:11<25:30,  1.61it/s]
# Iteration:  83% 12287/14751 [2:12:12<25:19,  1.62it/s]
# Iteration:  83% 12288/14751 [2:12:12<25:20,  1.62it/s]
# ...

# %% [markdown]
# ## Evaluate model
# ### Generate with generate_transformers.py script.

# %%
# !python ru-gpts/generate_transformers.py \
    --model_type=gpt2 \
    --model_name_or_path=drive/MyDrive/AI-dungeon/models/VK_test_mixed_dataset_gpt3_medium \
    --k=5 \
    --p=0.95 \
    --length=500 \
    --repetition_penalty=5
# Out:
# 11/12/2021 21:25:18 - INFO - __main__ -   Namespace(device=device(type='cuda'), k=5, length=500, model_name_or_path='drive/MyDrive/AI-dungeon/models/VK_test_mixed_dataset_gpt3_medium', model_type='gpt2', n_gpu=1, no_cuda=False, num_return_sequences=1, p=0.95, padding_text='', prompt='', repetition_penalty=5.0, seed=42, stop_token='</s>', temperature=1.0, xlm_language='')
# Context >>> Traceback (most recent call last):
#   File "ru-gpts/generate_transformers.py", line 268, in <module>
#     main()
#   File "ru-gpts/generate_transformers.py", line 213, in main
#     prompt_text = args.prompt if args.prompt else input("Context >>> ")
# KeyboardInterrupt

# %% [markdown]
# ### Generate mannualy

# %%
import numpy as np
import torch

# %%
np.random.seed(42)
torch.manual_seed(42)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tok_gpt = GPT2Tokenizer.from_pretrained("drive/MyDrive/AI-Dungeon/models/VK_test_mixed_dataset_gpt3_medium \")
# Out:
#   File "<ipython-input-26-133285a30b4d>", line 1
#     tok_gpt = GPT2Tokenizer.from_pretrained("drive/MyDrive/AI-Dungeon/models/VK_test_mixed_dataset_gpt3_medium \")
#                                                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
model_gpt = GPT2LMHeadModel.from_pretrained("drive/MyDrive/AI-Dungeon/models/VK_test_mixed_dataset_gpt3_medium")

# %%
model_gpt.cuda()

# %%
text = "<s>Тема: «Создает человека природа, но развивает и образует его общество». (В.Т. Белинский)\nСочинение: "
inpt = tok.encode(text, return_tensors="pt")

# %%
out = model_gpt.generate(inpt.cuda(), max_length=500, repetition_penalty=5.0, do_sample=True, top_k=5, top_p=0.95, temperature=1)

# %%
tok.decode(out[0])
